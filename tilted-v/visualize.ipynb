# %%
import xarray as xr

# %%
da = xr.open_dataarray("Overland_Kin_yneg/overland_tiltedV.out.press.00006.pfb", name="press")
# Out:
# Overland_Kin_yneg/overland_tiltedV.out.press.00006.pfb

# %%
da
# Out:
# <xarray.DataArray 'press' (z: 2, y: 25, x: 25)>
# array([[[-5.498486e+00, -5.498486e+00, ..., -5.498486e+00, -5.498486e+00],
#         [-5.498486e+00, -5.498486e+00, ..., -5.498486e+00, -5.498486e+00],
#         ...,
#         [-5.498486e+00, -5.498486e+00, ..., -5.498486e+00, -5.498486e+00],
#         [-5.498486e+00, -5.498486e+00, ..., -5.498486e+00, -5.498486e+00]],
#
#        [[ 3.554707e-04,  4.533760e-04, ...,  4.533760e-04,  3.554707e-04],
#         [ 4.533760e-04,  6.159817e-04, ...,  6.159817e-04,  4.533760e-04],
#         ...,
#         [ 5.387928e-04,  8.166570e-04, ...,  8.166570e-04,  5.387928e-04],
#         [ 5.387928e-04,  8.166571e-04, ...,  8.166571e-04,  5.387928e-04]]])
# Dimensions without coordinates: z, y, x

# %%
da.sel(z=1).plot.pcolormesh()
