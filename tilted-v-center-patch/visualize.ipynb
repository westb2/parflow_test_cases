# %%
import xarray as xr

# %%
da = xr.open_dataarray("Overland_Kin_xneg/overland_tiltedV.out.press.00003.pfb", name="press")
# Out:
# Overland_Kin_ypos/overland_tiltedV.out.press.00003.pfb

# %%
da
# Out:
# <xarray.DataArray 'press' (z: 2, y: 25, x: 25)>
# array([[[-5.499971, -5.499971, ..., -5.499971, -5.499971],
#         [-5.499971, -5.499971, ..., -5.499971, -5.499971],
#         ...,
#         [-5.499971, -5.499971, ..., -5.499971, -5.499971],
#         [-5.499971, -5.499971, ..., -5.499971, -5.499971]],
#
#        [[-0.151734, -0.151734, ..., -0.151734, -0.151734],
#         [-0.151734, -0.151734, ..., -0.151734, -0.151734],
#         ...,
#         [-0.151734, -0.151734, ..., -0.151734, -0.151734],
#         [-0.151734, -0.151734, ..., -0.151734, -0.151734]]])
# Dimensions without coordinates: z, y, x

# %%
da.sel(z=1).plot.pcolormesh()
